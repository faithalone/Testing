# %%
# Dependencies
import pandas as pd
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %%
# All CSV file location.
president_csv = "Resources/president.csv"
executive_csv = "Resources/executive_orders.csv"
subtopic_csv = "Resources/SubTopics.csv"
topcode_csv = "Resources/TopicCode.csv"

# %%
# Reading President Orders CSV file
president_df = pd.read_csv(president_csv)
president_df = president_df.astype({"executive_order_number": float})
president_df.head()
# Out:
#   citation document_number  end_page  \
# 0      NaN          94-290         0
# 1      NaN         94-1531         0
# 2      NaN         94-1532         0
# 3      NaN         94-2261         0
# 4      NaN         94-2267         0
#
#                                executive_order_notes  executive_order_number  \
# 0                                                NaN                 12890.0
# 1           Revoked by: EO 13062, September 29, 1997                 12891.0
# 2  Amends: EO 11063, November 20, 1962;;\n ;  Rev...                 12892.0
# 3  Revokes: EO 11063, November 20, 1962 (in part)...                 12893.0
# 4                  See: Memorandum, January 17, 1994                 12894.0
#
#                                             html_url pdf_url publication_date  \
# 0  https://www.federalregister.gov/documents/1994...     NaN       01/05/1994
# 1  https://www.federalregister.gov/documents/1994...     NaN       01/20/1994
# 2  https://www.federalregister.gov/documents/1994...     NaN       01/20/1994
# 3  https://www.federalregister.gov/documents/1994...     NaN       01/31/1994
# 4  https://www.federalregister.gov/documents/1994...     NaN       01/31/1994
#
#   signing_date  start_page                                              title
# 0   12/30/1993           0             Amendment to Executive Order No. 12864
# 1   01/15/1994           0  Advisory Committee on Human Radiation Experiments
# 2   01/17/1994           0  Leadership and Coordination of Fair Housing in...
# 3   01/26/1994           0  Principles for Federal Infrastructure Investments
# 4   01/26/1994           0          North Pacific Marine Science Organization

# %%
# Reading Executive Orders CSV file
executive_df = pd.read_csv(executive_csv)
executive_df.head()
# Out:
#    id  eo_number president  pres_party  beg_term  end_term  signed_date  year  \
# 0   1     9538.0    TRUMAN         100         1         0     19450413  1945
# 1   2     9539.0    TRUMAN         100         1         0     19450413  1945
# 2   3     9540.0    TRUMAN         100         1         0     19450417  1945
# 3   4     9541.0    TRUMAN         100         1         0     19450419  1945
# 4   5     9542.0    TRUMAN         100         1         0     19450423  1945
#
#    month  day  congress  divided  \
# 0      4   13        79        0
# 1      4   13        79        0
# 2      4   17        79        0
# 3      4   19        79        0
# 4      4   23        79        0
#
#                                          description  pap_majortopic  \
# 0  Authorizing certification for probational appo...              20
# 1  Reinstating Avra M. Warren in the Foreign Serv...              19
# 2  Authorizing the Petroleum Administrator to tak...              16
# 3  Transferring the Office of Surplus Property of...              20
# 4  Authorizing the Secretary of the Navy to take ...              16
#
#    pap_subtopic  majortopic  subtopic
# 0          2004          20      2004
# 1          1929          19      1929
# 2          1610          16      1610
# 3          2007          20      2007
# 4          1610          16      1610

# %%
# Reading SubTopic CSV file
subtopic_df = pd.read_csv(subtopic_csv, encoding='windows-1252')
subtopic_df.head()
# Out:
#    Code            SubTopic                                        Description
# 0   100             General   Includes issues related to general domestic m...
# 1   101      Interest Rates   Includes issues related to inflation, cost of...
# 2   103   Unemployment Rate   Includes issues related to the unemployment r...
# 3   104     Monetary Policy   Includes issues related to the monetary polic...
# 4   105     National Budget   Issues related to public debt, budgeting, and...
